# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#              algo     size  milliseconds
# 0        NaiveBWT    21504           220
# 1        NaiveBWT    39611           910
# 2        NaiveBWT    49379          1338
# 3        NaiveBWT    53161           741
# 4        NaiveBWT    71646          2050
# ..            ...      ...           ...
# 68  SuffixTreeBWT   102400            73
# 69  SuffixTreeBWT   111261            85
# 70  SuffixTreeBWT   246814           230
# 71  SuffixTreeBWT   768757           800
# 72  SuffixTreeBWT  1537514          8000
#
# [73 rows x 3 columns]

# %%
g = sns.lineplot(x='size',y='milliseconds',hue='algo',data=data)
# matplotlib.pyplot.xlim(0,9500000)
# matplotlib.pyplot.ylim(0,9800)

# %%
g = sns.lineplot(x='size',y='milliseconds',hue='algo',data=data)
matplotlib.pyplot.xlim(0,9500000)
matplotlib.pyplot.ylim(0,800)
# Out:
# (0, 800)
